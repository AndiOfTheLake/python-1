# %% [markdown]
# # 02 Intermediate Python

# %% [markdown]
# Sometimes we do not have direct access to pre-defined variables in Data Camp, in which case we create our own variables. At the end of the day, it is only the syntax that matters.

# %%
# import necessary packages

import numpy as np
import pandas as pd

# %% [markdown]
# ## Line plot 3
#
# The gdp data set was retrieved from
#
# https://assets.datacamp.com/production/repositories/287/datasets/5b1e4356f9fa5b5ce32e9bd2b75c777284819cca/gapminder.csv

# %%
dt1 = pd.read_csv("https://assets.datacamp.com/production/repositories/287/datasets/5b1e4356f9fa5b5ce32e9bd2b75c777284819cca/gapminder.csv")

dt1.head()
gdp_cap = dt1["gdp_cap"]
life_exp = dt1["life_exp"]

import matplotlib.pyplot as plt

# Make a line plot, gdp_cap on the x-axis, life_exp on the y-axis
plt.plot(gdp_cap, life_exp)

# Display the plot
plt.show()

# %% [markdown]
# ## Scatter plot 1

# %%
# Change the line plot below to a scatter plot
plt.scatter(gdp_cap, life_exp)

# Put the x-axis on a logarithmic scale
plt.xscale("log")

# Show plot
plt.show()

# %% [markdown]
# ## Scatter plot 2

# %%
# Import package
import matplotlib.pyplot as plt
pop = dt1["population"]

# Build Scatter plot
plt.scatter(pop, life_exp)

# Show plot
plt.show()

# %% [markdown]
# ## Build a histogram (1)

# %%
# Create histogram of life_exp data
plt.hist(life_exp)

# Display histogram
plt.show()

# %% [markdown]
# ## Build a histogram (2): bins

# %%
# Build histogram with 5 bins
plt.hist(life_exp, 5)

# Show and clean up plot
plt.show()
plt.clf()

# Build histogram with 20 bins
plt.hist(life_exp, 20)

# Show and clean up again
plt.show()
plt.clf()

# %% [markdown]
# ## customization

# %% [markdown]
# ## Labels

# %%
import matplotlib.pyplot as plt

# Basic scatter plot, log scale
plt.scatter(gdp_cap, life_exp)
plt.xscale('log') 

# Strings
xlab = 'GDP per Capita [in USD]'
ylab = 'Life Expectancy [in years]'
title = 'World Development in 2007'

# Add axis labels
plt.xlabel(xlab)
plt.ylabel(ylab)



# Add title
plt.title(title)

# After customizing, display the plot
plt.show()

# %% [markdown]
# ## Ticks

# %%
# Scatter plot
plt.scatter(gdp_cap, life_exp)

# Previous customizations
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')

# Definition of tick_val and tick_lab
tick_val = [1000, 10000, 100000]
tick_lab = ['1k', '10k', '100k']

# Adapt the ticks on the x-axis
plt.xticks(tick_val, tick_lab)

# After customizing, display the plot
plt.show()

# %%
# Import numpy as np
import numpy as np

# Store pop as a numpy array: np_pop
np_pop = np.array(pop)

# Double np_pop
np_pop = 2 * np_pop

# Update: set s argument to np_pop
plt.scatter(gdp_cap, life_exp, s = np_pop)

# Previous customizations
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks([1000, 10000, 100000],['1k', '10k', '100k'])

# Display the plot
plt.show()

# %% [markdown]
# Hmmmmm this does not quite look right. What's the problem? Well, in the Data camp example `pop` is pre loaded as a list. On the other hand, we have not yet converted the `pop` variable that we extracted from the data set to list:

# %%
type(pop)
# Out:
# pandas.core.series.Series

# %% [markdown]
# So let's do the converison right now. The code is retrieved from:
# https://note.nkmk.me/en/python-pandas-list/

# %%
pop = pop.values.tolist(); type(pop)
# Out:
# list

# %% [markdown]
# Now let us do the plot once again taking size into consideration.

# %%
# Import numpy as np
import numpy as np

# Store pop as a numpy array: np_pop
np_pop = np.array(pop)

# Double np_pop
np_pop =  2 * np_pop

# Update: set s argument to np_pop
plt.scatter(gdp_cap, life_exp, s = np_pop)

# Previous customizations
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks([1000, 10000, 100000],['1k', '10k', '100k'])

# Display the plot
plt.show()

# %%
len(pop)
# Out:
# 142

# %% [markdown]
# This is really weird. But we will copy-paste the code any way.

# %% [markdown]
# ## Dictionaries Part 1

# %% [markdown]
# ## Motivation for dictionaries

# %%
# Definition of countries and capital
countries = ['spain', 'france', 'germany', 'norway']
capitals = ['madrid', 'paris', 'berlin', 'oslo']

# Get index of 'germany': ind_ger
ind_ger = countries.index("germany")

# Use ind_ger to print out capital of Germany
print(capitals[ind_ger])
# Out:
# berlin

# %% [markdown]
# ## Acess dictionary

# %%
# Definition of dictionary
europe = {'spain':'madrid', 'france':'paris', 'germany':'berlin', 'norway':'oslo' }

# Print out the keys in europe
print(europe.keys())

# Print out value that belongs to key 'norway'
print(europe["norway"])
# Out:
# dict_keys(['spain', 'france', 'germany', 'norway'])
# oslo

# %% [markdown]
# ## Dictionaries, Part 2

# %% [markdown]
# ## Dictionary Manipulation (1)

# %%
# Definition of dictionary
europe = {'spain':'madrid', 'france':'paris', 'germany':'berlin', 'norway':'oslo' }

# Add italy to europe
europe["italy"] = "rome"

# Print out italy in europe
print('italy' in europe)

# Add poland to europe
europe['poland'] = 'warsaw'

# Print europe
print(europe)
# Out:
# True
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo', 'italy': 'rome', 'poland': 'warsaw'}

# %% [markdown]
# ## Dictionary Manipulation (2)

# %%
# Definition of dictionary
europe = {'spain':'madrid', 'france':'paris', 'germany':'bonn',
          'norway':'oslo', 'italy':'rome', 'poland':'warsaw',
          'australia':'vienna' }

# Update capital of germany
europe['germany'] = "berlin"

# Remove australia
del(europe['australia'])


# Print europe
print(europe)
# Out:
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo', 'italy': 'rome', 'poland': 'warsaw'}

# %% [markdown]
# ## Dictionariception

# %%
# Dictionary of dictionaries
europe = { 'spain': { 'capital':'madrid', 'population':46.77 },
           'france': { 'capital':'paris', 'population':66.03 },
           'germany': { 'capital':'berlin', 'population':80.62 },
           'norway': { 'capital':'oslo', 'population':5.084 } }


# Print out the capital of France
europe['france']['capital']

# Create sub-dictionary data
data = {'capital':'rome', 'population':59.83}

# Add data to europe under key 'italy'
europe['italy'] = data

# Print europe
print(europe)
# Out:
# {'spain': {'capital': 'madrid', 'population': 46.77}, 'france': {'capital': 'paris', 'population': 66.03}, 'germany': {'capital': 'berlin', 'population': 80.62}, 'norway': {'capital': 'oslo', 'population': 5.084}, 'italy': {'capital': 'rome', 'population': 59.83}}

# %% [markdown]
# ## Dictionary to DataFrame (1)

# %%
# Pre-defined lists
names = ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morocco', 'Egypt']
dr =  [True, False, False, False, True, True, True]
cpc = [809, 731, 588, 18, 200, 70, 45]

# Import pandas as pd
import pandas as pd

# Create dictionary my_dict with three key:value pairs: my_dict
my_dict = { 'country':names, 'drives_right':dr, 'cars_per_cap':cpc }

# Build a DataFrame cars from my_dict: cars
cars = pd.DataFrame(my_dict)

# Print cars
print(cars)
# Out:
#          country  drives_right  cars_per_cap
# 0  United States          True           809
# 1      Australia         False           731
# 2          Japan         False           588
# 3          India         False            18
# 4         Russia          True           200
# 5        Morocco          True            70
# 6          Egypt          True            45

# %% [markdown]
# Compare the dictionary above with the other dictionaries we have created earlier. Also notice that the columns of cars can be of different types, which is not possible with 2D Numpy arrays.

# %% [markdown]
# ## Dictionary to DataFrame (2)

# %%
import pandas as pd

# Build cars DataFrame
names = ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morocco', 'Egypt']
dr =  [True, False, False, False, True, True, True]
cpc = [809, 731, 588, 18, 200, 70, 45]
cars_dict = { 'country':names, 'drives_right':dr, 'cars_per_cap':cpc }
cars = pd.DataFrame(cars_dict)
print(cars)

# Definition of row_labels
row_labels = ['US', 'AUS', 'JPN', 'IN', 'RU', 'MOR', 'EG']

# Specify row labels of cars
cars.index = row_labels

# Print cars again
print(cars)
# Out:
#          country  drives_right  cars_per_cap
# 0  United States          True           809
# 1      Australia         False           731
# 2          Japan         False           588
# 3          India         False            18
# 4         Russia          True           200
# 5        Morocco          True            70
# 6          Egypt          True            45
#            country  drives_right  cars_per_cap
# US   United States          True           809
# AUS      Australia         False           731
# JPN          Japan         False           588
# IN           India         False            18
# RU          Russia          True           200
# MOR        Morocco          True            70
# EG           Egypt          True            45

# %% [markdown]
# ## CSV to DataFrame (1)

# %% [markdown]
# The `cars` data set is retrieved from:
# https://assets.datacamp.com/production/repositories/287/datasets/79b3c22c47a2f45a800c62cae39035ff2ea4e609/cars.csv

# %%
# Import pandas as pd
import pandas as pd

# Import the cars.csv data: cars
cars = pd.read_csv("https://assets.datacamp.com/production/repositories/287/datasets/79b3c22c47a2f45a800c62cae39035ff2ea4e609/cars.csv")

# Print out cars
print(cars)
# Out:
#   Unnamed: 0  cars_per_cap        country  drives_right
# 0         US           809  United States          True
# 1        AUS           731      Australia         False
# 2        JAP           588          Japan         False
# 3         IN            18          India         False
# 4         RU           200         Russia          True
# 5        MOR            70        Morocco          True
# 6         EG            45          Egypt          True

# %% [markdown]
# ## CSV to DataFrame (2)

# %%
# Fix import by including index_col
cars = pd.read_csv('https://assets.datacamp.com/production/repositories/287/datasets/79b3c22c47a2f45a800c62cae39035ff2ea4e609/cars.csv', 
                   index_col =0)

# Print out cars
print(cars)
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS           731      Australia         False
# JAP           588          Japan         False
# IN             18          India         False
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True

# %% [markdown]
# ## Square Brackets (1)

# %%
# Print out country column as Pandas Series
print(cars['country'])

# Print out country column as Pandas DataFrame
print(cars[['country']])

# Print out DataFrame with country and drives_right columns
print(cars[['country', 'drives_right']])
# Out:
# US     United States
# AUS        Australia
# JAP            Japan
# IN             India
# RU            Russia
# MOR          Morocco
# EG             Egypt
# Name: country, dtype: object
#            country
# US   United States
# AUS      Australia
# JAP          Japan
# IN           India
# RU          Russia
# MOR        Morocco
# EG           Egypt
#            country  drives_right
# US   United States          True
# AUS      Australia         False
# JAP          Japan         False
# IN           India         False
# RU          Russia          True
# MOR        Morocco          True
# EG           Egypt          True

# %% [markdown]
# ## Square Brackets (2)

# %%
# Print out first 3 observations
print(cars[:3])

# Print out fourth, fifth and sixth observation
print(cars[3:6])
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS           731      Australia         False
# JAP           588          Japan         False
#      cars_per_cap  country  drives_right
# IN             18    India         False
# RU            200   Russia          True
# MOR            70  Morocco          True

# %% [markdown]
# ## loc and iloc (1)

# %%
print(cars)
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS           731      Australia         False
# JAP           588          Japan         False
# IN             18          India         False
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True
# cars_per_cap      588
# country         Japan
# drives_right    False
# Name: JAP, dtype: object
# cars_per_cap      588
# country         Japan
# drives_right    False
# Name: JAP, dtype: object
#      cars_per_cap    country  drives_right
# AUS           731  Australia         False
# EG             45      Egypt          True
#      cars_per_cap    country  drives_right
# AUS           731  Australia         False
# EG             45      Egypt          True

# %%
# Print out observation for Japan as a pandas series using loc
print(cars.loc['JAP'])
# Out:
# cars_per_cap      588
# country         Japan
# drives_right    False
# Name: JAP, dtype: object
# cars_per_cap      588
# country         Japan
# drives_right    False
# Name: JAP, dtype: object

# %%
# Print out observation for Japan as a pandas series using iloc
print(cars.iloc[2])
# Out:
# cars_per_cap      588
# country         Japan
# drives_right    False
# Name: JAP, dtype: object

# %%
# Print out observations for Australia and Egypt as a DataFrame using loc
print(cars.loc[['AUS', 'EG']])
# Out:
#      cars_per_cap    country  drives_right
# AUS           731  Australia         False
# EG             45      Egypt          True

# %%
# Print out observations for Australia and Egypt as a DataFrame using iloc
print(cars.iloc[[1, 6]])
# Out:
#      cars_per_cap    country  drives_right
# AUS           731  Australia         False
# EG             45      Egypt          True

# %% [markdown]
# ## loc and iloc(2)

# %%
# Print out drives_right value of Morocco
print(cars.loc['MOR', 'drives_right'])

# Print sub-DataFrame
print(cars.loc[['RU','MOR'], ['country', 'drives_right']])
# Out:
# True
#      country  drives_right
# RU    Russia          True
# MOR  Morocco          True

# %% [markdown]
# ## loc and iloc (3)

# %%
# Print out drives_right column as Series using loc
print(cars.loc[:, 'drives_right'])
# Out:
# US      True
# AUS    False
# JAP    False
# IN     False
# RU      True
# MOR     True
# EG      True
# Name: drives_right, dtype: bool

# %%
# Print out drives_right column as Series using iloc
print(cars.iloc[:, 2])
# Out:
# US      True
# AUS    False
# JAP    False
# IN     False
# RU      True
# MOR     True
# EG      True
# Name: drives_right, dtype: bool

# %%
# Print out drives_right column as DataFrame using loc
print(cars.loc[:, ['drives_right']])
# Out:
#      drives_right
# US           True
# AUS         False
# JAP         False
# IN          False
# RU           True
# MOR          True
# EG           True

# %%
# Print out drives_right column as DataFrame using iloc
print(cars.iloc[:, [2]])
# Out:
#      drives_right
# US           True
# AUS         False
# JAP         False
# IN          False
# RU           True
# MOR          True
# EG           True

# %%
# Print out cars_per_cap and drives_right as DataFrame using loc
print(cars.loc[:, ['cars_per_cap', 'drives_right']])
# Out:
#      cars_per_cap  drives_right
# US            809          True
# AUS           731         False
# JAP           588         False
# IN             18         False
# RU            200          True
# MOR            70          True
# EG             45          True

# %%
# Print out cars_per_cap and drives_right as DataFrame using iloc
print(cars.iloc[:, [0,2]])
# Out:
#      cars_per_cap  drives_right
# US            809          True
# AUS           731         False
# JAP           588         False
# IN             18         False
# RU            200          True
# MOR            70          True
# EG             45          True

# %% [markdown]
# ## Comparison operators

# %%
# Comparison of booleans
print(True == False)

# Comparison of integers
print(-5 * 15 != 75)

# Comparison of strings
print("pyscript" != "PyScript")

# Compare a boolean with an integer
print(True == 1)
# Out:
# False
# True
# True
# True

# %%
# Comparison of integers
x = -3 * 6
print(x >= -10)

# Comparison of strings
y = "test"
print("test" <= y)

# Comparison of booleans
print(True > False)
# Out:
# False
# True
# True

# %%
# Create arrays
import numpy as np
my_house = np.array([18.0, 20.0, 10.75, 9.50])
your_house = np.array([14.0, 24.0, 14.25, 9.0])

# my_house greater than or equal to 18
print(my_house >= 18)

# my_house less than your_house
print(my_house < your_house)
# Out:
# [ True  True False False]
# [False  True  True False]

# %% [markdown]
# ## And, or, not (1)

# %%
# Define variables
my_kitchen = 18.0
your_kitchen = 14.0

# my_kitchen bigger than 10 and smaller than 18?
print(my_kitchen > 10 and my_kitchen < 18)

# my_kitchen smaller than 14 or bigger than 17?
print(my_kitchen < 14 or my_kitchen > 17)

# Double my_kitchen smaller than triple your_kitchen?
print(2*my_kitchen < 3* your_kitchen)
# Out:
# False
# True
# True

# %%
x = 8
y = 9
not(not(x < 3) and not(y > 14 or y > 10))
# Out:
# False

# %% [markdown]
# ## Boolean operators with Numpy

# %%
# Create arrays
import numpy as np
my_house = np.array([18.0, 20.0, 10.75, 9.50])
your_house = np.array([14.0, 24.0, 14.25, 9.0])

# my_house greater than 18.5 or smaller than 10
print(np.logical_or(my_house > 18.5, my_house<10))

# Both my_house and your_house smaller than 11
print(np.logical_and(my_house<11, your_house<11))
# Out:
# [False  True False  True]
# [False False False  True]

# %% [markdown]
# ## Control Flow
#
# We MUST press `tab` for the execution of a condition.

# %%
# Warm up
area = 10.0
if(area < 9) :
    print("small")
elif(area < 12) :
    print("medium")
else :
    print("large")
# Out:
# medium

# %%
# Define variables
room = "kit"
area = 14.0

# if statement for room
if room == "kit" :
    print("looking around in the kitchen.")

# if statement for area
if area > 15:
    print("big place!")
# Out:
# looking around in the kitchen.

# %%
# Define variables
room = "kit"
area = 14.0

# if-else construct for room
if room == "kit" :
    print("looking around in the kitchen.")
else :
    print("looking around elsewhere.")

# if-else construct for area
if area > 15 :
    print("big place!")
else : 
    print("pretty small.")
# Out:
# looking around in the kitchen.
# pretty small.

# %%
# Define variables
room = "bed"
area = 14.0

# if-elif-else construct for room
if room == "kit" :
    print("looking around in the kitchen.")
elif room == "bed":
    print("looking around in the bedroom.")
else :
    print("looking around elsewhere.")

# if-elif-else construct for area
if area > 15 :
    print("big place!")
elif area > 10 :
    print("medium size, nice!")
else :
    print("pretty small.")
# Out:
# looking around in the bedroom.
# medium size, nice!

# %% [markdown]
# ## Filtering Pandas DataFrames
#
# It is desirable to extra data set as Pandas series, NOT as DataFrames.

# %% [markdown]
# ## Driving right

# %%
# Extract drives_right column as Series: dr
dr = cars['drives_right']

# Use dr to subset cars: sel
sel = cars[dr]

# Print sel
print(sel)
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True

# %%
# Convert the same code to a one-liner
sel = cars[cars['drives_right']]

# Print sel
print(sel)
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True

# %% [markdown]
# ## cars per capita

# %%
# Create car_maniac: observations that have a cars_per_cap over 500
cpc = cars['cars_per_cap']
many_cars = cpc > 500
car_maniac = cars[many_cars]

# Print car_maniac
print(car_maniac)
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS           731      Australia         False
# JAP           588          Japan         False

# %%
# Create medium: observations with cars_per_cap between 100 and 500
cpc = cars['cars_per_cap']
between = np.logical_and(cpc>100, cpc<500)
medium = cars[between]


# Print medium
print(medium)
# Out:
#     cars_per_cap country  drives_right
# RU           200  Russia          True

# %% [markdown]
# ## While
#
# Be careful! If the while loop does not stop, press Ctrl + C. Again, we MUST indent the content of the loop.

# %%
# Initialize offset
offset = 8

# Code the while loop
while offset != 0 :
    offset = offset - 1
    print("correcting...")
    print(offset)
# Out:
# correcting...
# 7
# correcting...
# 6
# correcting...
# 5
# correcting...
# 4
# correcting...
# 3
# correcting...
# 2
# correcting...
# 1
# correcting...
# 0

# %%
# Initialize offset
offset = -6

# Code the while loop
while offset != 0 :
    print("correcting...")
    if offset > 0 :
      offset = offset - 1
    else : 
      offset = offset + 1    
    print(offset)
# Out:
# correcting...
# -5
# correcting...
# -4
# correcting...
# -3
# correcting...
# -2
# correcting...
# -1
# correcting...
# 0

# %% [markdown]
# ## For loop

# %%
# areas list
areas = [11.25, 18.0, 20.0, 10.75, 9.50]

# Code the for loop
for area in areas :
    print(area)
# Out:
# 11.25
# 18.0
# 20.0
# 10.75
# 9.5

# %% [markdown]
# ## Indexes and values
#
# To print the indeces, we can use the `enumerate()` function.

# %%
# areas list
areas = [11.25, 18.0, 20.0, 10.75, 9.50]

# Change for loop to use enumerate() and update print()
for index, area in enumerate(areas) :
    print("room" + str(index) + ": " + str(area))
# Out:
# room0: 11.25
# room1: 18.0
# room2: 20.0
# room3: 10.75
# room4: 9.5

# %% [markdown]
# For non-programmer folks, `room 0: 11.25` is a bit strange...

# %%
# areas list
areas = [11.25, 18.0, 20.0, 10.75, 9.50]

# Code the for loop
for index, area in enumerate(areas) :
    print("room " + str(index + 1) + ": " + str(area))
# Out:
# room 1: 11.25
# room 2: 18.0
# room 3: 20.0
# room 4: 10.75
# room 5: 9.5

# %%
# Loop over list of lists
# house list of lists
house = [["hallway", 11.25], 
         ["kitchen", 18.0], 
         ["living room", 20.0], 
         ["bedroom", 10.75], 
         ["bathroom", 9.50]]
         
# Build a for loop from scratch (pay attention to the spacing between strings)
for i in house : 
    print("the " + str(i[0]) + " is " + str(i[1]) + " sqm")
# Out:
# the hallway is 11.25 sqm
# the kitchen is 18.0 sqm
# the living room is 20.0 sqm
# the bedroom is 10.75 sqm
# the bathroom is 9.5 sqm

# %% [markdown]
# ## Loop data structures

# %%
# Loop over dictionary (requires a method)

# Definition of dictionary
europe = {'spain':'madrid', 'france':'paris', 'germany':'berlin',
          'norway':'oslo', 'italy':'rome', 'poland':'warsaw', 'austria':'vienna' }
          
# Iterate over europe
for key, value in europe.items() : 
    print("the capital of " + str(key) + " is " + str(value))
# Out:
# the capital of spain is madrid
# the capital of france is paris
# the capital of germany is berlin
# the capital of norway is oslo
# the capital of italy is rome
# the capital of poland is warsaw
# the capital of austria is vienna

# %% [markdown]
# # Looping over numpy array
#
# We do not have the pre defined data set, so we make up one.

# %%
np_height = np.array([75]* 10)
np_weight = np.array([200]*10)

# set random seed
import random as rd 
rd.seed(500)
e1 = np.random.normal(loc=0.0, scale=1.0, size=len(np_height))
e2 = np.random.normal(loc=200, scale=5.0, size=len(np_height))

np_height = np_height + e1
np_weight = np_weight + e2

np_baseball = np.column_stack((np_height, np_weight))
np_baseball.shape

# Import numpy as np
import numpy as np

# For loop over np_height
for i in np_height : 
    print(str(i) + " inches")

# For loop over np_baseball
for i in np.nditer(np_baseball) : 
    print(str(i))
# Out:
# 74.21039362784877 inches
# 74.61381932967643 inches
# 75.64661044861735 inches
# 77.01737621900871 inches
# 75.67205773962031 inches
# 75.55668302119757 inches
# 74.45516848429465 inches
# 74.38254914943802 inches
# 76.03272228313372 inches
# 75.60156547592986 inches
# 74.21039362784877
# 399.64557956899796
# 74.61381932967643
# 403.5582347173787
# 75.64661044861735
# 404.52911789461433
# 77.01737621900871
# 406.24336231817483
# 75.67205773962031
# 412.41741257705706
# 75.55668302119757
# 400.1436519310706
# 74.45516848429465
# 395.07054459377684
# 74.38254914943802
# 397.49944727385605
# 76.03272228313372
# 415.1982467888445
# 75.60156547592986
# 406.5597227974136

# %% [markdown]
# ## Loop over data frame

# %%
import pandas as pd

# Iterate over rows of cars
for lab, row in cars.iterrows() : 
    print(lab)
    print(row)
# Out:
# US
# cars_per_cap              809
# country         United States
# drives_right             True
# Name: US, dtype: object
# AUS
# cars_per_cap          731
# country         Australia
# drives_right        False
# Name: AUS, dtype: object
# JAP
# cars_per_cap      588
# country         Japan
# drives_right    False
# Name: JAP, dtype: object
# IN
# cars_per_cap       18
# country         India
# drives_right    False
# Name: IN, dtype: object
# RU
# cars_per_cap       200
# country         Russia
# drives_right      True
# Name: RU, dtype: object
# MOR
# cars_per_cap         70
# country         Morocco
# drives_right       True
# Name: MOR, dtype: object
# EG
# cars_per_cap       45
# country         Egypt
# drives_right     True
# Name: EG, dtype: object

# %%
# Adapt for loop
for lab, row in cars.iterrows() :
    print(lab + ": " + str(row['cars_per_cap']))
# Out:
# US: 809
# AUS: 731
# JAP: 588
# IN: 18
# RU: 200
# MOR: 70
# EG: 45

# %% [markdown]
# ## Add column

# %%
# Code for loop that adds COUNTRY column using for loop
for lab, row in cars.iterrows() : 
    cars.loc[lab, "COUNTRY"] = row['country'].upper()


# Print cars
print(cars)
# Out:
#      cars_per_cap        country  drives_right        COUNTRY
# US            809  United States          True  UNITED STATES
# AUS           731      Australia         False      AUSTRALIA
# JAP           588          Japan         False          JAPAN
# IN             18          India         False          INDIA
# RU            200         Russia          True         RUSSIA
# MOR            70        Morocco          True        MOROCCO
# EG             45          Egypt          True          EGYPT

# %% [markdown]
# ## The brics data
#
# The data is retrieved from
#
# https://assets.datacamp.com/production/repositories/287/datasets/b60fb5bdbeb4e4ab0545c485d351e6ff5428a155/brics.csv

# %%
brics = pd.read_csv("https://assets.datacamp.com/production/repositories/287/datasets/b60fb5bdbeb4e4ab0545c485d351e6ff5428a155/brics.csv")

# %%
# Add a column using for loop

for lab, row in brics.iterrows() :
    brics.loc[lab, "name_length"] = len(row["country"])
print(brics)
# Out:
#   Unnamed: 0       country    capital    area  population  name_length
# 0         BR        Brazil   Brasilia   8.516      200.40          6.0
# 1         RU        Russia     Moscow  17.100      143.50          6.0
# 2         IN         India  New Delhi   3.286     1252.00          5.0
# 3         CH         China    Beijing   9.597     1357.00          5.0
# 4         SA  South Africa   Pretoria   1.221       52.98         12.0

# %%
# Add a column using apply function

brics["name_length"] = brics["country"].apply(len)
print(brics)
# Out:
#   Unnamed: 0       country    capital    area  population  name_length
# 0         BR        Brazil   Brasilia   8.516      200.40            6
# 1         RU        Russia     Moscow  17.100      143.50            6
# 2         IN         India  New Delhi   3.286     1252.00            5
# 3         CH         China    Beijing   9.597     1357.00            5
# 4         SA  South Africa   Pretoria   1.221       52.98           12

# %% [markdown]
# We can do a similar thing to call the `upper()` method on every name in the `country` column. However, `upper()` is a method, so we'll need a slightly different approach: we apply `str.upper`.

# %%
# Add a column using apply function (compare with previous code chunk!)

# Use .apply(str.upper)
cars["COUNTRY"] = cars["country"].apply(str.upper)
print(cars)
# Out:
#      cars_per_cap        country  drives_right        COUNTRY
# US            809  United States          True  UNITED STATES
# AUS           731      Australia         False      AUSTRALIA
# JAP           588          Japan         False          JAPAN
# IN             18          India         False          INDIA
# RU            200         Russia          True         RUSSIA
# MOR            70        Morocco          True        MOROCCO
# EG             45          Egypt          True          EGYPT

# %% [markdown]
# ## Random numbers
#
# We set random seed using the `random` package, a sub-package of `numpy`.

# %%
# Import numpy as np
import numpy as np

# Set the seed
np.random.seed(123)

# Generate and print random float
print(np.random.rand())
# Out:
# 0.6964691855978616

# %%
## ROLL THE DICE

# Set seed
np.random.seed(123)

# Use randint() to simulate a dice
print(np.random.randint(1, 7))

# Use randint() again
print(np.random.randint(1, 7))
# Out:
# 6
# 3

# %%
## DETERMINE YOUR NEXT MOVE

# Numpy is imported, seed is set
import numpy as np
np.random.seed(123)

# Starting step
step = 50

# Roll the dice
dice = np.random.randint(1, 7)

# Finish the control construct
if dice <= 2 :
    step = step - 1
elif dice <=5 :
    step = step + 1
else :
    step = step + np.random.randint(1,7)

# Print out dice and step
print(dice)
print(step)
# Out:
# 6
# 53

# %% [markdown]
# ## Random walk

# %%
# Numpy is imported, seed is set
import numpy as np
np.random.seed(123)

# Initialize random_walk
random_walk = [0]

# Complete the for loop which runs 100 times
for x in range(100) :
    # Set step: last element in random_walk
    step = random_walk[-1]

    # Roll the dice
    dice = np.random.randint(1,7)

    # Determine next step
    if dice <= 2:
        step = step - 1
    elif dice <= 5:
        step = step + 1
    else:
        step = step + np.random.randint(1,7)

    # append next_step to random_walk
    random_walk.append(step)

# Print random_walk
print(random_walk)
# Out:
# [0, 3, 4, 5, 4, 5, 6, 7, 6, 5, 4, 3, 2, 1, 0, -1, 0, 5, 4, 3, 4, 3, 4, 5, 6, 7, 8, 7, 8, 7, 8, 9, 10, 11, 10, 14, 15, 14, 15, 14, 15, 16, 17, 18, 19, 20, 21, 24, 25, 26, 27, 32, 33, 37, 38, 37, 38, 39, 38, 39, 40, 42, 43, 44, 43, 42, 43, 44, 43, 42, 43, 44, 46, 45, 44, 45, 44, 45, 46, 47, 49, 48, 49, 50, 51, 52, 53, 52, 51, 52, 51, 52, 53, 52, 55, 56, 57, 58, 57, 58, 59]

# %%
len(random_walk)
# Out:
# 101

# %%
## HOW LOW CAN YOU GO? WE CANNOT GO BELOW 0.

# Numpy is imported, seed is set
import numpy as np
np.random.seed(123)

# Initialize random_walk
random_walk = [0]

for x in range(100) :
    step = random_walk[-1]
    dice = np.random.randint(1,7)

    if dice <= 2:
        # Replace below: use max to make sure step can't go below 0
        step = max(step - 1, 0)
    elif dice <= 5:
        step = step + 1
    else:
        step = step + np.random.randint(1,7)

    random_walk.append(step)

print(random_walk)
# Out:
# [0, 3, 4, 5, 4, 5, 6, 7, 6, 5, 4, 3, 2, 1, 0, 0, 1, 6, 5, 4, 5, 4, 5, 6, 7, 8, 9, 8, 9, 8, 9, 10, 11, 12, 11, 15, 16, 15, 16, 15, 16, 17, 18, 19, 20, 21, 22, 25, 26, 27, 28, 33, 34, 38, 39, 38, 39, 40, 39, 40, 41, 43, 44, 45, 44, 43, 44, 45, 44, 43, 44, 45, 47, 46, 45, 46, 45, 46, 47, 48, 50, 49, 50, 51, 52, 53, 54, 53, 52, 53, 52, 53, 54, 53, 56, 57, 58, 59, 58, 59, 60]

# %%
## VISUALIZE THE WALK

# Numpy is imported, seed is set
import numpy as np
np.random.seed(123)

# Initialization
random_walk = [0]

for x in range(100) :
    step = random_walk[-1]
    dice = np.random.randint(1,7)

    if dice <= 2:
        step = max(0, step - 1)
    elif dice <= 5:
        step = step + 1
    else:
        step = step + np.random.randint(1,7)

    random_walk.append(step)

# Import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# Plot random_walk
plt.plot(random_walk)

# Show the plot
plt.show()

# %% [markdown]
# ## Simulate multiple walks

# %%
# Numpy is imported; seed is set
import numpy as np
np.random.seed(123)

# Initialize all_walks (don't change this line)
all_walks = []

# Simulate random walk 10 times
for i in range(10) :

    # Code from before
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)

        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        random_walk.append(step)

    # Append random_walk to all_walks
    all_walks.append(random_walk)

# Print all_walks
print(all_walks)
# Out:
# [[0, 3, 4, 5, 4, 5, 6, 7, 6, 5, 4, 3, 2, 1, 0, 0, 1, 6, 5, 4, 5, 4, 5, 6, 7, 8, 9, 8, 9, 8, 9, 10, 11, 12, 11, 15, 16, 15, 16, 15, 16, 17, 18, 19, 20, 21, 22, 25, 26, 27, 28, 33, 34, 38, 39, 38, 39, 40, 39, 40, 41, 43, 44, 45, 44, 43, 44, 45, 44, 43, 44, 45, 47, 46, 45, 46, 45, 46, 47, 48, 50, 49, 50, 51, 52, 53, 54, 53, 52, 53, 52, 53, 54, 53, 56, 57, 58, 59, 58, 59, 60], [0, 4, 3, 2, 4, 3, 4, 6, 7, 8, 13, 12, 13, 14, 15, 16, 17, 16, 21, 22, 23, 24, 23, 22, 21, 20, 19, 20, 21, 22, 28, 27, 26, 25, 26, 27, 28, 27, 28, 29, 28, 33, 34, 33, 32, 31, 30, 31, 30, 29, 31, 32, 35, 36, 38, 39, 40, 41, 40, 39, 40, 41, 42, 43, 42, 43, 44, 45, 48, 49, 50, 49, 50, 49, 50, 51, 52, 56, 55, 54, 55, 56, 57, 56, 57, 56, 57, 59, 64, 63, 64, 65, 66, 67, 68, 69, 68, 69, 70, 71, 73], [0, 2, 1, 2, 3, 6, 5, 6, 5, 6, 7, 8, 7, 8, 7, 8, 9, 11, 10, 9, 10, 11, 10, 12, 13, 14, 15, 16, 17, 18, 17, 18, 19, 24, 25, 24, 23, 22, 21, 22, 23, 24, 29, 30, 29, 30, 31, 32, 33, 34, 35, 34, 33, 34, 33, 39, 38, 39, 38, 39, 38,
# ...

# %% [markdown]
# ## Visualize all walks
#
# The following instructions are retrieved from Data Camp.
#
# Use `np.array()` to convert all_walks to a Numpy array, `np_aw`.
# Try to use `plt.plot()` on `np_aw`. Also include `plt.show()`. Does it work out of the box?
# Transpose np_aw by calling `np.transpose()` on `np_aw`. Call the result `np_aw_t`. Now every row in `np_all_walks` represents the position after 1 throw for the 10 random walks.
# Use `plt.plot()` to plot `np_aw_t`; also include a `plt.show()`. Does it look better this time?

# %%
# numpy and matplotlib imported, seed set.
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(123)

# initialize and populate all_walks
all_walks = []
for i in range(10) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        random_walk.append(step)
    all_walks.append(random_walk)

# Convert all_walks to Numpy array: np_aw
np_aw = np.array(all_walks)

# Plot np_aw and show
plt.plot(np_aw)
plt.show()

# Clear the figure
plt.clf()

# Transpose np_aw: np_aw_t
np_aw_t = np.transpose(np_aw)

# Plot np_aw_t and show
plt.plot(np_aw_t)
plt.show()

# %% [markdown]
# ## Implement clumsiness
#
# Now suppose we are clumsy and have a 0.1% chance of falling down (i.e. step = 0).

# %%
# numpy and matplotlib imported, seed set
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(123)

# Simulate random walk 250 times
all_walks = []
for i in range(250) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)

        # Implement clumsiness
        if  np.random.rand() <= 0.001 :
            step = 0

        random_walk.append(step)
    all_walks.append(random_walk)

# Create and plot np_aw_t
np_aw_t = np.transpose(np.array(all_walks))
plt.plot(np_aw_t)
plt.show()

# %% [markdown]
# ## Plot the distribution

# %%
# numpy and matplotlib imported, seed set
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(123)


# Simulate random walk 500 times
all_walks = []
for i in range(500) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        if np.random.rand() <= 0.001 :
            step = 0
        random_walk.append(step)
    all_walks.append(random_walk)

# Create and plot np_aw_t
np_aw_t = np.transpose(np.array(all_walks))

# Select last row from np_aw_t: ends
ends = np_aw_t[-1,:]

# Plot histogram of ends, display plot
plt.hist(ends)
plt.show()

# %% [markdown]
# ## Calculating the proportion
#
# Finally, we calculate the proportion such that the end point is greater than or equal to 60.

# %%
len(ends[ends >=60]) / 500
# Out:
# 0.784
